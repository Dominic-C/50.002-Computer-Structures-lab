# %%
X_and1 A[30:0] B[1]#31 Z2[30:0] and2
X_FA_1 Z1[1] Z2[0] 0 alu[1] CO1[0] FA
X_FA_1_rest Z1[31:2] Z2[30:1] CO1[29:0] Z3[30:1] CO1[30:1] FA

X_and2 A[29:0] B[2]#30 Z4[29:0] and2
X_FA_2 Z3[1] Z4[0] 0 alu[2] CO2[0] FA 
X_FA_2_rest Z3[30:2] Z4[29:1] CO2[28:0] Z5[29:1] CO2[29:1] FA

X_and3 A[28:0] B[3]#29 Z6[29:0] and2
X_FA_3 Z5[1] Z6[0] 0 alu[3] CO3[0] FA
X_FA_3_rest Z5[29:2] Z6[28:1] CO3[27:0] Z7[28:1] CO3[28:1] FA

# %%
for i in range(31):
    print("X_and{} A[{}:0] B[{}]#{} Z{}[{}:0] and2".format(i+1, 30-i, i+1,31-i, 2*(i+1), 30-i))
    print("X_FA_{} Z{}[1] Z{}[0] 0 alu[{}] CO{}[0] FA".format(i+1, 2*(i+1)-1, 2*(i+1), i+1, i+1))
    print("X_FA_{}_rest Z{}[{}:2] Z{}[{}:1] CO{}[{}:0] Z{}[{}:1] CO{}[{}:1] FA\n".format(i+1, 2*(i+1)-1, 31-i, 2*(i+1), 30-i, i+1, 30-1-i, 2*(i+1)+1, 30-i,i+1, 30-i))
# Out:
# X_and1 A[30:0] B[1]#31 Z2[30:0] and2
# X_FA_1 Z1[1] Z2[0] 0 alu[1] CO1[0] FA
# X_FA_1_rest Z1[31:2] Z2[30:1] CO1[29:0] Z3[30:1] CO1[30:1] FA
#
# X_and2 A[29:0] B[2]#30 Z4[29:0] and2
# X_FA_2 Z3[1] Z4[0] 0 alu[2] CO2[0] FA
# X_FA_2_rest Z3[30:2] Z4[29:1] CO2[28:0] Z5[29:1] CO2[29:1] FA
#
# X_and3 A[28:0] B[3]#29 Z6[28:0] and2
# X_FA_3 Z5[1] Z6[0] 0 alu[3] CO3[0] FA
# X_FA_3_rest Z5[29:2] Z6[28:1] CO3[27:0] Z7[28:1] CO3[28:1] FA
#
# X_and4 A[27:0] B[4]#28 Z8[27:0] and2
# X_FA_4 Z7[1] Z8[0] 0 alu[4] CO4[0] FA
# X_FA_4_rest Z7[28:2] Z8[27:1] CO4[26:0] Z9[27:1] CO4[27:1] FA
#
# X_and5 A[26:0] B[5]#27 Z10[26:0] and2
# X_FA_5 Z9[1] Z10[0] 0 alu[5] CO5[0] FA
# X_FA_5_rest Z9[27:2] Z10[26:1] CO5[25:0] Z11[26:1] CO5[26:1] FA
#
# X_and6 A[25:0] B[6]#26 Z12[25:0] and2
# X_FA_6 Z11[1] Z12[0] 0 alu[6] CO6[0] FA
# X_FA_6_rest Z11[26:2] Z12[25:1] CO6[24:0] Z13[25:1] CO6[25:1] FA
#
# X_and7 A[24:0] B[7]#25 Z14[24:0] and2
# X_FA_7 Z13[1] Z14[0] 0 alu[7] CO7[0] FA
# ...

# %% [raw]
# X_and2 A[30:0] B[1]#31 Z2Z[30:0] and2
# X_FA_B1_F Z1Z[1] Z2Z[0] 0 P[1] C1out[0] FA
# X_FA_B1_L Z1Z[31:2] Z2Z[30:1] C1out[29:0] Z3Z[30:1] C1out[30:1] FA
#
# X_and3 A[29:0] B[2]#30 Z4Z[29:0] and2
# X_FA_B2_F Z3Z[1] Z4Z[0] 0 P[2] C2out[0] FA
# X_FA_B2_L Z3Z[30:2] Z4Z[29:1] C2out[28:0] Z5Z[29:1] C2out[29:1] FA
#
# X_and4 A[28:0] B[3]#29 Z6Z[28:0] and2
# X_FA_B3_F Z5Z[1] Z6Z[0] 0 P[3] C3out[0] FA
# X_FA_B3_L Z5Z[29:2] Z6Z[28:1] C3out[27:0] Z7Z[28:1] C3out[28:1] FA

# %%
a = 2
b = 1
c = 0
d = 2

for i in range(31):
    print("X_and{} A[{}:0] B[{}]#{} Z{}Z[{}:0] and2".format(a,30-c, a-1, 31-c, d, 30-c))
    print("X_FA_B{}_F Z{}Z[1] Z{}Z[0] 0 alu[{}] C{}out[0] FA".format(c+1, d-1, d, a-1, b))
    print("X_FA_B{}_L Z{}Z[{}:2] Z{}Z[{}:1] C{}out[{}:0] Z{}Z[{}:1] C{}out[{}:1] FA\n".format(c+1, d-1,31 -c, d, 30-c, b, 29-c, d+1, 30-c, b, 30-c))
    a += 1
    c += 1
    d += 2
    b += 1
# Out:
# X_and2 A[30:0] B[1]#31 Z2Z[30:0] and2
# X_FA_B1_F Z1Z[1] Z2Z[0] 0 alu[1] C1out[0] FA
# X_FA_B1_L Z1Z[31:2] Z2Z[30:1] C1out[29:0] Z3Z[30:1] C1out[30:1] FA
#
# X_and3 A[29:0] B[2]#30 Z4Z[29:0] and2
# X_FA_B2_F Z3Z[1] Z4Z[0] 0 alu[2] C2out[0] FA
# X_FA_B2_L Z3Z[30:2] Z4Z[29:1] C2out[28:0] Z5Z[29:1] C2out[29:1] FA
#
# X_and4 A[28:0] B[3]#29 Z6Z[28:0] and2
# X_FA_B3_F Z5Z[1] Z6Z[0] 0 alu[3] C3out[0] FA
# X_FA_B3_L Z5Z[29:2] Z6Z[28:1] C3out[27:0] Z7Z[28:1] C3out[28:1] FA
#
# X_and5 A[27:0] B[4]#28 Z8Z[27:0] and2
# X_FA_B4_F Z7Z[1] Z8Z[0] 0 alu[4] C4out[0] FA
# X_FA_B4_L Z7Z[28:2] Z8Z[27:1] C4out[26:0] Z9Z[27:1] C4out[27:1] FA
#
# X_and6 A[26:0] B[5]#27 Z10Z[26:0] and2
# X_FA_B5_F Z9Z[1] Z10Z[0] 0 alu[5] C5out[0] FA
# X_FA_B5_L Z9Z[27:2] Z10Z[26:1] C5out[25:0] Z11Z[26:1] C5out[26:1] FA
#
# X_and7 A[25:0] B[6]#26 Z12Z[25:0] and2
# X_FA_B6_F Z11Z[1] Z12Z[0] 0 alu[6] C6out[0] FA
# X_FA_B6_L Z11Z[26:2] Z12Z[25:1] C6out[24:0] Z13Z[25:1] C6out[25:1] FA
#
# X_and8 A[24:0] B[7]#25 Z14Z[24:0] and2
# ...

# %%
X_and2 A[30:0] B[1]#31 Z2Z[30:0] and2
X_FA_B1_F Z1Z[1] Z2Z[0] 0 P[1] C1out[0] FA
X_FA_B1_L Z1Z[31:2] Z2Z[30:1] C1out[29:0] Z3Z[30:1] C1out[30:1] FA

X_and3 A[29:0] B[2]#30 Z4Z[29:0] and2
X_FA_B2_F Z3Z[1] Z4Z[0] 0 P[2] C2out[0] FA
X_FA_B2_L Z3Z[30:2] Z4Z[29:1] C2out[28:0] Z5Z[29:1] C2out[29:1] FA

X_and4 A[28:0] B[3]#29 Z6Z[28:0] and2
X_FA_B3_F Z5Z[1] Z6Z[0] 0 P[3] C3out[0] FA
X_FA_B3_L Z5Z[29:2] Z6Z[28:1] C3out[27:0] Z7Z[28:1] C3out[28:1] FA
